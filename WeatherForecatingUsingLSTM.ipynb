# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from xgboost import plot_importance, plot_tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
# Out:
# C:\Users\pooji\anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# Loading Dataset

# %%
d = pd.read_csv(r'C:\Users\pooji\Desktop\Project\WeatherJena.csv')
d
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2010 00:10:00    967.56     -2.84    272.89        -3.41
# 1       01.01.2010 00:20:00    967.45     -2.85    272.88        -3.43
# 2       01.01.2010 00:30:00    967.45     -2.88    272.85        -3.46
# 3       01.01.2010 00:40:00    967.34     -2.90    272.84        -3.47
# 4       01.01.2010 00:50:00    967.29     -2.96    272.78        -3.53
# ...                     ...       ...       ...       ...          ...
# 656951  30.06.2022 23:20:00    984.33     22.00    296.49        19.85
# 656952  30.06.2022 23:30:00    984.20     21.92    296.42        19.91
# 656953  30.06.2022 23:40:00    984.18     21.77    296.27        19.84
# 656954  30.06.2022 23:50:00    984.24     21.67    296.16        19.83
# 656955  01.07.2022 00:00:00    984.27     22.20    296.69        19.73
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  ...  \
# 0         95.8          4.95          4.75          0.21       3.06  ...
# 1         95.7          4.95          4.74          0.21       3.05  ...
# 2         95.8          4.94          4.73          0.21       3.05  ...
# 3         95.8          4.93          4.72          0.21       3.04  ...
# 4         95.8          4.91          4.70          0.21       3.03  ...
# ...        ...           ...           ...           ...        ...  ...
# 656951    87.6         26.48         23.20          3.28      14.79  ...
# 656952    88.4         26.35         23.30          3.06      14.86  ...
# 656953    88.8         26.11         23.19          2.92      14.79  ...
# 656954    89.3         25.95         23.18          2.78      14.78  ...
# 656955    85.9         26.81         23.03          3.78      14.68  ...
#
#         wv (m/s)  max. wv (m/s)  wd (deg)  rain (mm)  raining (s)  \
# 0           1.61           2.76     15.41        0.0            0
# 1           2.00           3.10     17.04        0.0            0
# 2           2.25           3.79     25.35        0.0            0
# 3           2.64           3.77     23.64        0.0          270
# 4           2.82           4.29     18.94        0.0          310
# ...          ...            ...       ...        ...          ...
# 656951      1.04           1.34     40.23        0.0            0
# 656952      1.07           1.49     31.68        0.0            0
# 656953      0.46           0.79    222.00        0.0            0
# 656954      0.97           1.64    233.30        0.0            0
# 656955      1.38           1.78    229.70        0.0            0
#
#         SWDR (W/m�)  PAR (�mol/m�/s)  max. PAR (�mol/m�/s)  Tlog (degC)  \
# 0               0.0              0.0                   0.0         8.59
# 1               0.0              0.0                   0.0         8.53
# 2               0.0              0.0                   0.0         8.52
# 3               0.0              0.0                   0.0         8.54
# 4               0.0              0.0                   0.0         8.55
# ...             ...              ...                   ...          ...
# 656951          0.0              0.0                   0.0        32.45
# 656952          0.0              0.0                   0.0        32.30
# 656953          0.0              0.0                   0.0        32.14
# 656954          0.0              0.0                   0.0        31.99
# 656955          0.0              0.0                   0.0        31.85
#
#         CO2 (ppm)
# 0           404.6
# 1           404.1
# 2           404.3
# 3           404.0
# 4           401.9
# ...           ...
# 656951      445.8
# 656952      446.2
# 656953      446.3
# 656954      443.9
# 656955      441.9
#
# [656956 rows x 22 columns]

# %% [markdown]
# Removing null columns

# %%
d=d[['Date Time','p (mbar)','T (degC)','Tpot (K)','Tdew (degC)','rh (%)','VPmax (mbar)','VPact (mbar)','VPdef (mbar)','sh (g/kg)','H2OC (mmol/mol)','rho (g/m**3)','wv (m/s)', 'max. wv (m/s)','wd (deg)','rain (mm)',
'CO2 (ppm)']]  
d
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2010 00:10:00    967.56     -2.84    272.89        -3.41
# 1       01.01.2010 00:20:00    967.45     -2.85    272.88        -3.43
# 2       01.01.2010 00:30:00    967.45     -2.88    272.85        -3.46
# 3       01.01.2010 00:40:00    967.34     -2.90    272.84        -3.47
# 4       01.01.2010 00:50:00    967.29     -2.96    272.78        -3.53
# ...                     ...       ...       ...       ...          ...
# 656951  30.06.2022 23:20:00    984.33     22.00    296.49        19.85
# 656952  30.06.2022 23:30:00    984.20     21.92    296.42        19.91
# 656953  30.06.2022 23:40:00    984.18     21.77    296.27        19.84
# 656954  30.06.2022 23:50:00    984.24     21.67    296.16        19.83
# 656955  01.07.2022 00:00:00    984.27     22.20    296.69        19.73
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# 0         95.8          4.95          4.75          0.21       3.06
# 1         95.7          4.95          4.74          0.21       3.05
# 2         95.8          4.94          4.73          0.21       3.05
# 3         95.8          4.93          4.72          0.21       3.04
# 4         95.8          4.91          4.70          0.21       3.03
# ...        ...           ...           ...           ...        ...
# 656951    87.6         26.48         23.20          3.28      14.79
# 656952    88.4         26.35         23.30          3.06      14.86
# 656953    88.8         26.11         23.19          2.92      14.79
# 656954    89.3         25.95         23.18          2.78      14.78
# 656955    85.9         26.81         23.03          3.78      14.68
#
#         H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)  \
# 0                  4.91       1244.56      1.61           2.76     15.41
# 1                  4.90       1244.48      2.00           3.10     17.04
# 2                  4.89       1244.65      2.25           3.79     25.35
# 3                  4.88       1244.57      2.64           3.77     23.64
# 4                  4.86       1244.81      2.82           4.29     18.94
# ...                 ...           ...       ...            ...       ...
# 656951            23.57       1151.44      1.04           1.34     40.23
# 656952            23.67       1151.55      1.07           1.49     31.68
# 656953            23.56       1152.16      0.46           0.79    222.00
# 656954            23.55       1152.63      0.97           1.64    233.30
# 656955            23.39       1150.66      1.38           1.78    229.70
#
#         rain (mm)  CO2 (ppm)
# 0             0.0      404.6
# 1             0.0      404.1
# 2             0.0      404.3
# 3             0.0      404.0
# 4             0.0      401.9
# ...           ...        ...
# 656951        0.0      445.8
# 656952        0.0      446.2
# 656953        0.0      446.3
# 656954        0.0      443.9
# 656955        0.0      441.9
#
# [656956 rows x 17 columns]

# %% [markdown]
# Data Analysis

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 656956 entries, 0 to 656955
# Data columns (total 17 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Date Time        656956 non-null  object
#  1   p (mbar)         656956 non-null  float64
#  2   T (degC)         656956 non-null  float64
#  3   Tpot (K)         656956 non-null  float64
#  4   Tdew (degC)      656956 non-null  float64
#  5   rh (%)           656956 non-null  float64
#  6   VPmax (mbar)     656956 non-null  float64
#  7   VPact (mbar)     656956 non-null  float64
#  8   VPdef (mbar)     656956 non-null  float64
#  9   sh (g/kg)        656956 non-null  float64
#  10  H2OC (mmol/mol)  656956 non-null  float64
#  11  rho (g/m**3)     656956 non-null  float64
#  12  wv (m/s)         656956 non-null  float64
#  13  max. wv (m/s)    656956 non-null  float64
#  14  wd (deg)         656956 non-null  float64
#  15  rain (mm)        656956 non-null  float64
#  16  CO2 (ppm)        656956 non-null  float64
# dtypes: float64(16), object(1)
# memory usage: 85.2+ MB

# %% [markdown]
# Changing Date column datatype to datetime

# %%
d['Date Time']= pd.to_datetime(d['Date Time'])
# Out:
# C:\Users\pooji\AppData\Local\Temp\ipykernel_11752\3582922921.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['Date Time']= pd.to_datetime(d['Date Time'])

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 656956 entries, 0 to 656955
# Data columns (total 17 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Date Time        656956 non-null  datetime64[ns]
#  1   p (mbar)         656956 non-null  float64
#  2   T (degC)         656956 non-null  float64
#  3   Tpot (K)         656956 non-null  float64
#  4   Tdew (degC)      656956 non-null  float64
#  5   rh (%)           656956 non-null  float64
#  6   VPmax (mbar)     656956 non-null  float64
#  7   VPact (mbar)     656956 non-null  float64
#  8   VPdef (mbar)     656956 non-null  float64
#  9   sh (g/kg)        656956 non-null  float64
#  10  H2OC (mmol/mol)  656956 non-null  float64
#  11  rho (g/m**3)     656956 non-null  float64
#  12  wv (m/s)         656956 non-null  float64
#  13  max. wv (m/s)    656956 non-null  float64
#  14  wd (deg)         656956 non-null  float64
#  15  rain (mm)        656956 non-null  float64
#  16  CO2 (ppm)        656956 non-null  float64
# dtypes: datetime64[ns](1), float64(16)
# memory usage: 85.2 MB

# %%
# Sorting by the date 
d.sort_values('Date Time', inplace=True)
# Out:
# C:\Users\pooji\AppData\Local\Temp\ipykernel_11752\3765387152.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d.sort_values('Date Time', inplace=True)

# %%
d
# Out:
#                  Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0      2010-01-01 00:10:00    967.56     -2.84    272.89        -3.41   95.80
# 1      2010-01-01 00:20:00    967.45     -2.85    272.88        -3.43   95.70
# 2      2010-01-01 00:30:00    967.45     -2.88    272.85        -3.46   95.80
# 3      2010-01-01 00:40:00    967.34     -2.90    272.84        -3.47   95.80
# 4      2010-01-01 00:50:00    967.29     -2.96    272.78        -3.53   95.80
# ...                    ...       ...       ...       ...          ...     ...
# 654358 2022-12-06 23:10:00    991.63     18.46    292.31         8.86   53.51
# 654359 2022-12-06 23:20:00    991.58     18.50    292.36         8.59   52.41
# 654360 2022-12-06 23:30:00    991.52     18.63    292.49         8.37   51.22
# 654361 2022-12-06 23:40:00    991.55     18.58    292.44         8.32   51.18
# 654362 2022-12-06 23:50:00    991.51     18.21    292.07         8.18   51.91
#
#         VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 0               4.95          4.75          0.21       3.06             4.91
# 1               4.95          4.74          0.21       3.05             4.90
# 2               4.94          4.73          0.21       3.05             4.89
# 3               4.93          4.72          0.21       3.04             4.88
# 4               4.91          4.70          0.21       3.03             4.86
# ...              ...           ...           ...        ...              ...
# 654358         21.28         11.39          9.89       7.17            11.48
# 654359         21.33         11.18         10.15       7.04            11.27
# 654360         21.51         11.02         10.49       6.94            11.11
# 654361         21.44         10.97         10.47       6.91            11.07
# 654362         20.95         10.87         10.07       6.85            10.97
#
#         rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)  rain (mm)  CO2 (ppm)
# 0            1244.56      1.61           2.76     15.41        0.0      404.6
# 1            1244.48      2.00           3.10     17.04        0.0      404.1
# 2            1244.65      2.25           3.79     25.35        0.0      404.3
# 3            1244.57      2.64           3.77     23.64        0.0      404.0
# 4            1244.81      2.82           4.29     18.94        0.0      401.9
# ...              ...       ...            ...       ...        ...        ...
# 654358       1179.47      0.53           1.49    345.40        0.0      422.3
# 654359       1179.34      1.64           2.09    331.70        0.0      421.0
# 654360       1178.82      2.26           2.74    335.10        0.0      420.4
# 654361       1179.08      1.57           2.45    325.00        0.0      421.1
# 654362       1180.57      1.06           1.77    316.00        0.0      422.5
#
# [656956 rows x 17 columns]

# %%
d.describe()
# Out:
#             p (mbar)       T (degC)       Tpot (K)    Tdew (degC)  \
# count  656956.000000  656956.000000  656956.000000  656956.000000
# mean      989.629414       9.865185     283.873995       5.138933
# std         8.593790       8.283449       8.387817       6.570250
# min       913.600000     -21.040000     251.480000     -23.390000
# 25%       984.530000       3.690000     277.670000       0.410000
# 50%       989.970000       9.570000     283.630000       5.270000
# 75%       995.230000      15.830000     289.870000      10.190000
# max      1020.070000      37.280000     311.340000      23.110000
#
#               rh (%)   VPmax (mbar)   VPact (mbar)   VPdef (mbar)  \
# count  656956.000000  656956.000000  656956.000000  656956.000000
# mean       75.124650      13.909444       9.622059       4.287313
# std        17.216312       7.900362       4.179659       5.175657
# min        12.950000       1.130000       0.920000       0.000000
# 25%        63.630000       7.960000       6.290000       0.930000
# 50%        78.300000      11.940000       8.900000       2.310000
# 75%        89.100000      18.010000      12.450000       5.630000
# max       100.000000      63.770000      28.320000      47.810000
#
#            sh (g/kg)  H2OC (mmol/mol)   rho (g/m**3)       wv (m/s)  \
# count  656956.000000    656956.000000  656956.000000  656956.000000
# mean        6.076697         9.726866    1214.724769       1.839576
# std         2.654493         4.232323      39.558745      53.806316
# min         0.570000         0.910000    1059.450000   -9999.000000
# 25%         3.970000         6.360000    1186.020000       0.990000
# 50%         5.610000         8.990000    1213.280000       1.740000
# 75%         7.870000        12.590000    1242.370000       2.840000
# max        18.130000        28.820000    1393.540000      28.490000
#
#        max. wv (m/s)       wd (deg)      rain (mm)      CO2 (ppm)
# count  656956.000000  656956.000000  656956.000000  656956.000000
# mean        3.247453     175.305706       0.009195     387.611696
# std        55.240310      85.730048       0.107539     553.680753
# min     -9999.000000       0.000000       0.000000   -9999.000000
# 25%         1.760000     125.800000       0.000000     402.700000
# 50%         2.960000     198.100000       0.000000     414.600000
# 75%         4.760000     233.600000       0.000000     428.000000
# max        23.500000     360.000000      18.900000     586.000000

# %%
sns.distplot(d[['T (degC)']])
# Out:
# C:\Users\pooji\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Feature Selection using correlation

# %%
#correlation matrix

corrmat = d.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
new_d=d[['Date Time','T (degC)','Tpot (K)','Tdew (degC)', 'VPmax (mbar)','VPact (mbar)','VPdef (mbar)','sh (g/kg)','H2OC (mmol/mol)','rho (g/m**3)','rh (%)']]

# %% [markdown]
# Extracted features

# %%
new_d
# Out:
#                  Date Time  T (degC)  Tpot (K)  Tdew (degC)  VPmax (mbar)  \
# 0      2010-01-01 00:10:00     -2.84    272.89        -3.41          4.95
# 1      2010-01-01 00:20:00     -2.85    272.88        -3.43          4.95
# 2      2010-01-01 00:30:00     -2.88    272.85        -3.46          4.94
# 3      2010-01-01 00:40:00     -2.90    272.84        -3.47          4.93
# 4      2010-01-01 00:50:00     -2.96    272.78        -3.53          4.91
# ...                    ...       ...       ...          ...           ...
# 654358 2022-12-06 23:10:00     18.46    292.31         8.86         21.28
# 654359 2022-12-06 23:20:00     18.50    292.36         8.59         21.33
# 654360 2022-12-06 23:30:00     18.63    292.49         8.37         21.51
# 654361 2022-12-06 23:40:00     18.58    292.44         8.32         21.44
# 654362 2022-12-06 23:50:00     18.21    292.07         8.18         20.95
#
#         VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 0               4.75          0.21       3.06             4.91       1244.56
# 1               4.74          0.21       3.05             4.90       1244.48
# 2               4.73          0.21       3.05             4.89       1244.65
# 3               4.72          0.21       3.04             4.88       1244.57
# 4               4.70          0.21       3.03             4.86       1244.81
# ...              ...           ...        ...              ...           ...
# 654358         11.39          9.89       7.17            11.48       1179.47
# 654359         11.18         10.15       7.04            11.27       1179.34
# 654360         11.02         10.49       6.94            11.11       1178.82
# 654361         10.97         10.47       6.91            11.07       1179.08
# 654362         10.87         10.07       6.85            10.97       1180.57
#
#         rh (%)
# 0        95.80
# 1        95.70
# 2        95.80
# 3        95.80
# 4        95.80
# ...        ...
# 654358   53.51
# 654359   52.41
# 654360   51.22
# 654361   51.18
# 654362   51.91
#
# [656956 rows x 11 columns]

# %% [markdown]
# Data Cleaning - Removal of outliers using Z-score

# %%
#Using z_scores to remove outliers


cols = ['T (degC)','Tpot (K)','Tdew (degC)','VPmax (mbar)','VPact (mbar)','VPdef (mbar)','sh (g/kg)','H2OC (mmol/mol)','rho (g/m**3)','rh (%)']


def z_score(new_d):
    new_d.columns = [x + "_zscore" for x in new_d.columns.tolist()]
    return ((new_d - new_d.mean())/new_d.std(ddof=0))

# %%
z_scores = z_score(new_d[cols])
z_scores['ID'] = z_scores.index
z_scores
# Out:
#         T (degC)_zscore  Tpot (K)_zscore  Tdew (degC)_zscore  \
# 0             -1.533805        -1.309519           -1.301159
# 1             -1.535012        -1.310711           -1.304203
# 2             -1.538634        -1.314288           -1.308769
# 3             -1.541048        -1.315480           -1.310291
# 4             -1.548292        -1.322633           -1.319423
# ...                 ...              ...                 ...
# 654358         1.037590         1.005746            0.566351
# 654359         1.042419         1.011707            0.525257
# 654360         1.058113         1.027206            0.491773
# 654361         1.052076         1.021244            0.484163
# 654362         1.007409         0.977133            0.462854
#
#         VPmax (mbar)_zscore  VPact (mbar)_zscore  VPdef (mbar)_zscore  \
# 0                 -1.134056            -1.165660            -0.787787
# 1                 -1.134056            -1.168053            -0.787787
# 2                 -1.135321            -1.170445            -0.787787
# 3                 -1.136587            -1.172838            -0.787787
# 4                 -1.139119            -1.177623            -0.787787
# ...                     ...                  ...                  ...
# 654358             0.932940             0.422987             1.082508
# 654359             0.939268             0.372744             1.132744
# 654360             0.962052             0.334463             1.198436
# 654361             0.953192             0.322500             1.194571
# 654362             0.891169             0.298575             1.117287
#
#         sh (g/kg)_zscore  H2OC (mmol/mol)_zscore  rho (g/m**3)_zscore  \
# 0              -1.136450               -1.138115             0.754201
# 1              -1.140217               -1.140478             0.752179
# 2              -1.140217               -1.142841             0.756476
# 3              -1.143985               -1.145203             0.754454
# 4              -1.147752               -1.149929             0.760521
# ...                  ...                     ...                  ...
# 654358          0.411869                0.414225            -0.891201
# 654359          0.362896                0.364607            -0.894487
# 654360          0.325224                0.326803            -0.907632
# 654361          0.313922                0.317352            -0.901060
# 654362          0.291319                0.293724            -0.863394
#
#         rh (%)_zscore      ID
# 0            1.200917       0
# 1            1.195109       1
# 2            1.200917       2
# 3            1.200917       3
# 4            1.200917       4
# ...               ...     ...
# 654358      -1.255476  654358
# 654359      -1.319369  654359
# 654360      -1.388490  654360
# 654361      -1.390813  654361
# 654362      -1.348411  654362
#
# [656956 rows x 11 columns]

# %%
new_d['ID'] = new_d.index
new_d = pd.merge(new_d, z_scores)
new_d
# Out:
# C:\Users\pooji\AppData\Local\Temp\ipykernel_11752\2775430772.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_d['ID'] = new_d.index
#                  Date Time  T (degC)  Tpot (K)  Tdew (degC)  VPmax (mbar)  \
# 0      2010-01-01 00:10:00     -2.84    272.89        -3.41          4.95
# 1      2010-01-01 00:20:00     -2.85    272.88        -3.43          4.95
# 2      2010-01-01 00:30:00     -2.88    272.85        -3.46          4.94
# 3      2010-01-01 00:40:00     -2.90    272.84        -3.47          4.93
# 4      2010-01-01 00:50:00     -2.96    272.78        -3.53          4.91
# ...                    ...       ...       ...          ...           ...
# 656951 2022-12-06 23:10:00     18.46    292.31         8.86         21.28
# 656952 2022-12-06 23:20:00     18.50    292.36         8.59         21.33
# 656953 2022-12-06 23:30:00     18.63    292.49         8.37         21.51
# 656954 2022-12-06 23:40:00     18.58    292.44         8.32         21.44
# 656955 2022-12-06 23:50:00     18.21    292.07         8.18         20.95
#
#         VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 0               4.75          0.21       3.06             4.91       1244.56
# 1               4.74          0.21       3.05             4.90       1244.48
# 2               4.73          0.21       3.05             4.89       1244.65
# 3               4.72          0.21       3.04             4.88       1244.57
# 4               4.70          0.21       3.03             4.86       1244.81
# ...              ...           ...        ...              ...           ...
# 656951         11.39          9.89       7.17            11.48       1179.47
# 656952         11.18         10.15       7.04            11.27       1179.34
# 656953         11.02         10.49       6.94            11.11       1178.82
# 656954         10.97         10.47       6.91            11.07       1179.08
# 656955         10.87         10.07       6.85            10.97       1180.57
#
#         ...  T (degC)_zscore  Tpot (K)_zscore  Tdew (degC)_zscore  \
# 0       ...        -1.533805        -1.309519           -1.301159
# 1       ...        -1.535012        -1.310711           -1.304203
# 2       ...        -1.538634        -1.314288           -1.308769
# 3       ...        -1.541048        -1.315480           -1.310291
# 4       ...        -1.548292        -1.322633           -1.319423
# ...     ...              ...              ...                 ...
# 656951  ...         1.037590         1.005746            0.566351
# 656952  ...         1.042419         1.011707            0.525257
# 656953  ...         1.058113         1.027206            0.491773
# 656954  ...         1.052076         1.021244            0.484163
# 656955  ...         1.007409         0.977133            0.462854
#
#         VPmax (mbar)_zscore  VPact (mbar)_zscore  VPdef (mbar)_zscore  \
# 0                 -1.134056            -1.165660            -0.787787
# 1                 -1.134056            -1.168053            -0.787787
# 2                 -1.135321            -1.170445            -0.787787
# 3                 -1.136587            -1.172838            -0.787787
# 4                 -1.139119            -1.177623            -0.787787
# ...                     ...                  ...                  ...
# 656951             0.932940             0.422987             1.082508
# 656952             0.939268             0.372744             1.132744
# 656953             0.962052             0.334463             1.198436
# 656954             0.953192             0.322500             1.194571
# 656955             0.891169             0.298575             1.117287
#
#         sh (g/kg)_zscore  H2OC (mmol/mol)_zscore  rho (g/m**3)_zscore  \
# 0              -1.136450               -1.138115             0.754201
# 1              -1.140217               -1.140478             0.752179
# 2              -1.140217               -1.142841             0.756476
# 3              -1.143985               -1.145203             0.754454
# 4              -1.147752               -1.149929             0.760521
# ...                  ...                     ...                  ...
# 656951          0.411869                0.414225            -0.891201
# 656952          0.362896                0.364607            -0.894487
# 656953          0.325224                0.326803            -0.907632
# 656954          0.313922                0.317352            -0.901060
# 656955          0.291319                0.293724            -0.863394
#
#         rh (%)_zscore
# 0            1.200917
# 1            1.195109
# 2            1.200917
# 3            1.200917
# 4            1.200917
# ...               ...
# 656951      -1.255476
# 656952      -1.319369
# 656953      -1.388490
# 656954      -1.390813
# 656955      -1.348411
#
# [656956 rows x 22 columns]

# %%
new_d = new_d.loc[new_d['T (degC)'].abs()>=3]
new_d = new_d.loc[new_d['Tpot (K)'].abs()>=3]
new_d = new_d.loc[new_d['Tdew (degC)'].abs()>=3]
new_d = new_d.loc[new_d['VPmax (mbar)'].abs()>=3]
new_d = new_d.loc[new_d['VPact (mbar)'].abs()>=3]
new_d = new_d.loc[new_d['VPdef (mbar)'].abs()>=3]
new_d = new_d.loc[new_d['sh (g/kg)'].abs()>=3]
new_d = new_d.loc[new_d['H2OC (mmol/mol)'].abs()>=3]
new_d = new_d.loc[new_d['rho (g/m**3)'].abs()>=3]
new_d = new_d.loc[new_d['rh (%)'].abs()>=3]
new_d = new_d.drop(columns =['T (degC)_zscore','Tpot (K)_zscore','Tdew (degC)_zscore','VPmax (mbar)_zscore','VPact (mbar)_zscore','VPdef (mbar)_zscore','sh (g/kg)_zscore','H2OC (mmol/mol)_zscore','rho (g/m**3)_zscore','rh (%)_zscore','ID'])
new_d.reset_index(drop=True, inplace=True)
new_d
# Out:
#                  Date Time  T (degC)  Tpot (K)  Tdew (degC)  VPmax (mbar)  \
# 0      2010-01-03 16:00:00      5.91    280.57        -3.14          9.30
# 1      2010-01-03 16:10:00      5.83    280.48        -3.01          9.25
# 2      2010-01-04 09:00:00      5.93    280.54        -3.06          9.31
# 3      2010-01-04 09:10:00      5.83    280.42        -3.07          9.25
# 4      2010-01-04 11:30:00      7.08    281.57        -3.44         10.08
# ...                    ...       ...       ...          ...           ...
# 227803 2022-12-06 23:10:00     18.46    292.31         8.86         21.28
# 227804 2022-12-06 23:20:00     18.50    292.36         8.59         21.33
# 227805 2022-12-06 23:30:00     18.63    292.49         8.37         21.51
# 227806 2022-12-06 23:40:00     18.58    292.44         8.32         21.44
# 227807 2022-12-06 23:50:00     18.21    292.07         8.18         20.95
#
#         VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 0               4.84          4.46       3.07             4.93       1222.87
# 1               4.89          4.36       3.10             4.98       1223.29
# 2               4.87          4.44       3.09             4.96       1223.44
# 3               4.87          4.38       3.09             4.95       1224.17
# 4               4.73          5.35       3.00             4.81       1220.46
# ...              ...           ...        ...              ...           ...
# 227803         11.39          9.89       7.17            11.48       1179.47
# 227804         11.18         10.15       7.04            11.27       1179.34
# 227805         11.02         10.49       6.94            11.11       1178.82
# 227806         10.97         10.47       6.91            11.07       1179.08
# 227807         10.87         10.07       6.85            10.97       1180.57
#
#         rh (%)
# 0        52.06
# 1        52.87
# 2        52.34
# 3        52.64
# 4        46.96
# ...        ...
# 227803   53.51
# 227804   52.41
# 227805   51.22
# 227806   51.18
# 227807   51.91
#
# [227808 rows x 11 columns]

# %%
sns.distplot(new_d[['T (degC)']])
# Out:
# C:\Users\pooji\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Skewness is reduced in the distribution

# %%
plt.plot(new_d[['T (degC)']])

# %%
new_d .set_index('Date Time',drop=True,inplace=True)

# %%
new_d
# Out:
#                      T (degC)  Tpot (K)  Tdew (degC)  VPmax (mbar)  \
# Date Time
# 2010-01-03 16:00:00      5.91    280.57        -3.14          9.30
# 2010-01-03 16:10:00      5.83    280.48        -3.01          9.25
# 2010-01-04 09:00:00      5.93    280.54        -3.06          9.31
# 2010-01-04 09:10:00      5.83    280.42        -3.07          9.25
# 2010-01-04 11:30:00      7.08    281.57        -3.44         10.08
# ...                       ...       ...          ...           ...
# 2022-12-06 23:10:00     18.46    292.31         8.86         21.28
# 2022-12-06 23:20:00     18.50    292.36         8.59         21.33
# 2022-12-06 23:30:00     18.63    292.49         8.37         21.51
# 2022-12-06 23:40:00     18.58    292.44         8.32         21.44
# 2022-12-06 23:50:00     18.21    292.07         8.18         20.95
#
#                      VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# Date Time
# 2010-01-03 16:00:00          4.84          4.46       3.07             4.93
# 2010-01-03 16:10:00          4.89          4.36       3.10             4.98
# 2010-01-04 09:00:00          4.87          4.44       3.09             4.96
# 2010-01-04 09:10:00          4.87          4.38       3.09             4.95
# 2010-01-04 11:30:00          4.73          5.35       3.00             4.81
# ...                           ...           ...        ...              ...
# 2022-12-06 23:10:00         11.39          9.89       7.17            11.48
# 2022-12-06 23:20:00         11.18         10.15       7.04            11.27
# 2022-12-06 23:30:00         11.02         10.49       6.94            11.11
# 2022-12-06 23:40:00         10.97         10.47       6.91            11.07
# 2022-12-06 23:50:00         10.87         10.07       6.85            10.97
#
#                      rho (g/m**3)  rh (%)
# Date Time
# 2010-01-03 16:00:00       1222.87   52.06
# 2010-01-03 16:10:00       1223.29   52.87
# 2010-01-04 09:00:00       1223.44   52.34
# 2010-01-04 09:10:00       1224.17   52.64
# 2010-01-04 11:30:00       1220.46   46.96
# ...                           ...     ...
# 2022-12-06 23:10:00       1179.47   53.51
# 2022-12-06 23:20:00       1179.34   52.41
# 2022-12-06 23:30:00       1178.82   51.22
# 2022-12-06 23:40:00       1179.08   51.18
# 2022-12-06 23:50:00       1180.57   51.91
#
# [227808 rows x 10 columns]

# %%
target=new_d[['T (degC)']]
new_d.drop(['T (degC)'], axis=1)
# Out:
#                      Tpot (K)  Tdew (degC)  VPmax (mbar)  VPact (mbar)  \
# Date Time
# 2010-01-03 16:00:00    280.57        -3.14          9.30          4.84
# 2010-01-03 16:10:00    280.48        -3.01          9.25          4.89
# 2010-01-04 09:00:00    280.54        -3.06          9.31          4.87
# 2010-01-04 09:10:00    280.42        -3.07          9.25          4.87
# 2010-01-04 11:30:00    281.57        -3.44         10.08          4.73
# ...                       ...          ...           ...           ...
# 2022-12-06 23:10:00    292.31         8.86         21.28         11.39
# 2022-12-06 23:20:00    292.36         8.59         21.33         11.18
# 2022-12-06 23:30:00    292.49         8.37         21.51         11.02
# 2022-12-06 23:40:00    292.44         8.32         21.44         10.97
# 2022-12-06 23:50:00    292.07         8.18         20.95         10.87
#
#                      VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# Date Time
# 2010-01-03 16:00:00          4.46       3.07             4.93       1222.87
# 2010-01-03 16:10:00          4.36       3.10             4.98       1223.29
# 2010-01-04 09:00:00          4.44       3.09             4.96       1223.44
# 2010-01-04 09:10:00          4.38       3.09             4.95       1224.17
# 2010-01-04 11:30:00          5.35       3.00             4.81       1220.46
# ...                           ...        ...              ...           ...
# 2022-12-06 23:10:00          9.89       7.17            11.48       1179.47
# 2022-12-06 23:20:00         10.15       7.04            11.27       1179.34
# 2022-12-06 23:30:00         10.49       6.94            11.11       1178.82
# 2022-12-06 23:40:00         10.47       6.91            11.07       1179.08
# 2022-12-06 23:50:00         10.07       6.85            10.97       1180.57
#
#                      rh (%)
# Date Time
# 2010-01-03 16:00:00   52.06
# 2010-01-03 16:10:00   52.87
# 2010-01-04 09:00:00   52.34
# 2010-01-04 09:10:00   52.64
# 2010-01-04 11:30:00   46.96
# ...                     ...
# 2022-12-06 23:10:00   53.51
# 2022-12-06 23:20:00   52.41
# 2022-12-06 23:30:00   51.22
# 2022-12-06 23:40:00   51.18
# 2022-12-06 23:50:00   51.91
#
# [227808 rows x 9 columns]

# %% [markdown]
# Data Transformation using MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
Ms = MinMaxScaler()
new_d [new_d.columns] = Ms.fit_transform(new_d)

# %% [markdown]
# Train-Test split

# %%
training_size = round(len(new_d) * 0.80)

# %%
train_data = new_d [:training_size]
target_train = target [:training_size]
target_test = target [training_size:]
test_data  = new_d [training_size:]

# %% [markdown]
# #### Prediction with XGBoost

# %%
reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(train_data, target_train,)
# Out:
# C:\Users\pooji\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=12,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
xgbpredictions = pd.DataFrame(reg.predict(test_data))
xgbpredictions=xgbpredictions[[0]]
index=target_test.index.copy()
a=pd.DataFrame(index)
xgbpredictions=pd.concat([a, xgbpredictions], axis=1, ignore_index=True)
xgbpredictions.rename(columns = {0:'Date Time', 1:'T (degC)' }, inplace = True)
xgbpredictions .set_index('Date Time',drop=True,inplace=True)

# %%
plt.figure(figsize=(30, 10))
plt.plot(target_test, label='actual')
plt.plot(xgbpredictions, linestyle='dashed', label='XGBoost forecast')
plt.title('Predicted Range')
plt.legend()
plt.show()

# %% [markdown]
# ##### Performance Evaluation

# %%
mean_squared_error(y_true=target_test,
                   y_pred=xgbpredictions)
# Out:
# 6.5283223658774494e-06

# %%
mean_absolute_error(y_true=target_test,
                   y_pred=xgbpredictions)
# Out:
# 0.0005856826609835741

# %% [markdown]
# ##### Random Forest Regressor

# %%
model = RandomForestRegressor()
model.fit(train_data, target_train)
# make a one-step prediction
yhat = model.predict(test_data)
# Out:
# C:\Users\pooji\AppData\Local\Temp\ipykernel_11752\1288478765.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(train_data, target_train)

# %%
yhat = pd.DataFrame(yhat)
index=target_test.index.copy()
a=pd.DataFrame(index)
yhat=pd.concat([a, yhat], axis=1, ignore_index=True)
yhat.rename(columns = {0:'Date Time', 1:'T (degC)' }, inplace = True)
yhat .set_index('Date Time',drop=True,inplace=True)

# %%
plt.figure(figsize=(30, 10))
plt.plot(target_test, label='actual')
plt.plot(yhat, linestyle='dashed', label='Random Forest forecast')
plt.title('Predicted Range')
plt.legend()
plt.show()

# %% [markdown]
# ##### Performance Evaluation

# %%
mean_squared_error(y_true=target_test,
                   y_pred=yhat)
# Out:
# 5.256119134365319e-07

# %%
mean_absolute_error(y_true=target_test,
                   y_pred=yhat)
# Out:
# 3.8626487007771064e-05

# %% [markdown]
# LSTM Model

# %%
train_data, test_data = np.array(train_data), np.array(test_data)
train_data = np.reshape(train_data, (train_data.shape[0], train_data.shape[1], 1))

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
model = Sequential()
model.add(LSTM(units=10, return_sequences=True, input_shape = (train_data.shape[1],1)))

model.add(Dropout(0.1)) 
model.add(LSTM(units=10))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10, 10)            480
#
#  dropout (Dropout)           (None, 10, 10)            0
#
#  lstm_1 (LSTM)               (None, 10)                840
#
#  dense (Dense)               (None, 2)                 22
#
# =================================================================
# Total params: 1,342
# Trainable params: 1,342
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(train_data, target_train, epochs=30,validation_data=(test_data, target_test), verbose=1)
# Out:
# Epoch 1/30
# 5696/5696 [==============================] - 55s 9ms/step - loss: 41.5358 - mean_absolute_error: 4.1760 - val_loss: 0.8363 - val_mean_absolute_error: 0.5454
# Epoch 2/30
# 5696/5696 [==============================] - 48s 8ms/step - loss: 0.3097 - mean_absolute_error: 0.3167 - val_loss: 0.0499 - val_mean_absolute_error: 0.1656
# Epoch 3/30
# 5696/5696 [==============================] - 47s 8ms/step - loss: 0.0705 - mean_absolute_error: 0.1996 - val_loss: 0.0213 - val_mean_absolute_error: 0.1081
# Epoch 4/30
# 5696/5696 [==============================] - 48s 8ms/step - loss: 0.0513 - mean_absolute_error: 0.1722 - val_loss: 0.0191 - val_mean_absolute_error: 0.1008
# Epoch 5/30
# 5696/5696 [==============================] - 48s 8ms/step - loss: 0.0421 - mean_absolute_error: 0.1563 - val_loss: 0.0274 - val_mean_absolute_error: 0.1360
# Epoch 6/30
# 5696/5696 [==============================] - 48s 8ms/step - loss: 0.0362 - mean_absolute_error: 0.1451 - val_loss: 0.0144 - val_mean_absolute_error: 0.0900
# Epoch 7/30
# 5696/5696 [==============================] - 49s 9ms/step - loss: 0.0327 - mean_absolute_error: 0.1376 - val_loss: 0.0116 - val_mean_absolute_error: 0.0825
# Epoch 8/30
# 5696/5696 [==============================] - 50s 9ms/step - loss: 0.0293 - mean_absolute_error: 0.1296 - val_loss: 0.0100 - val_mean_absolute_error: 0.0720
# Epoch 9/30
# 5696/5696 [==============================] - 49s 9ms/step - loss: 0.0265 - mean_absolute_error: 0.1234 - val_loss: 0.0079 - val_mean_absolute_error: 0.0688
# Epoch 10/30
# 5696/5696 [==============================] - 50s 9ms/step - loss: 0.0240 - mean_absolute_error: 0.1169 - val_loss: 0.0081 - val_mean_absolute_error: 0.0705
# Epoch 11/30
# 5696/5696 [==============================] - 49s 9ms/step - loss: 0.0218 - mean_absolute_error: 0.1117 - val_loss: 0.0083 - val_mean_absolute_error: 0.0720
# Epoch 12/30
# 5696/5696 [==============================] - 51s 9ms/step - loss: 0.0201 - mean_absolute_error: 0.1067 - val_loss: 0.0071 - val_mean_absolute_error: 0.0630
# Epoch 13/30
# 5696/5696 [==============================] - 50s 9ms/step - loss: 0.0186 - mean_absolute_error: 0.1025 - val_loss: 0.0110 - val_mean_absolute_error: 0.0844
# Epoch 14/30
# 5696/5696 [==============================] - 50s 9ms/step - loss: 0.0169 - mean_absolute_error: 0.0977 - val_loss: 0.0092 - val_mean_absolute_error: 0.0752
# Epoch 15/30
# 5696/5696 [==============================] - 50s 9ms/step - loss: 0.0160 - mean_absolute_error: 0.0950 - val_loss: 0.0063 - val_mean_absolute_error: 0.0624
# Epoch 16/30
# 5696/5696 [==============================] - 49s 9ms/step - loss: 0.0151 - mean_absolute_error: 0.0918 - val_loss: 0.0044 - val_mean_absolute_error: 0.0525
# Epoch 17/30
# 5696/5696 [==============================] - 50s 9ms/step - loss: 0.0143 - mean_absolute_error: 0.0896 - val_loss: 0.0128 - val_mean_absolute_error: 0.0885
# Epoch 18/30
# 5696/5696 [==============================] - 50s 9ms/step - loss: 0.0135 - mean_absolute_error: 0.0869 - val_loss: 0.0144 - val_mean_absolute_error: 0.1055
# Epoch 19/30
# 5696/5696 [==============================] - 50s 9ms/step - loss: 0.0130 - mean_absolute_error: 0.0854 - val_loss: 0.0047 - val_mean_absolute_error: 0.0534
# Epoch 20/30
# 5696/5696 [==============================] - 50s 9ms/step - loss: 0.0125 - mean_absolute_error: 0.0834 - val_loss: 0.0055 - val_mean_absolute_error: 0.0563
# Epoch 21/30
# 5696/5696 [==============================] - 50s 9ms/step - loss: 0.0118 - mean_absolute_error: 0.0815 - val_loss: 0.0024 - val_mean_absolute_error: 0.0366
# Epoch 22/30
# 5696/5696 [==============================] - 50s 9ms/step - loss: 0.0115 - mean_absolute_error: 0.0796 - val_loss: 0.0063 - val_mean_absolute_error: 0.0570
# Epoch 23/30
# 5696/5696 [==============================] - 50s 9ms/step - loss: 0.0110 - mean_absolute_error: 0.0780 - val_loss: 0.0033 - val_mean_absolute_error: 0.0433
# Epoch 24/30
# 5696/5696 [==============================] - 50s 9ms/step - loss: 0.0104 - mean_absolute_error: 0.0762 - val_loss: 0.0061 - val_mean_absolute_error: 0.0599
# Epoch 25/30
# 5696/5696 [==============================] - 50s 9ms/step - loss: 0.0102 - mean_absolute_error: 0.0749 - val_loss: 0.0042 - val_mean_absolute_error: 0.0515
# Epoch 26/30
# 5696/5696 [==============================] - 50s 9ms/step - loss: 0.0099 - mean_absolute_error: 0.0737 - val_loss: 0.0045 - val_mean_absolute_error: 0.0546
# Epoch 27/30
# 5696/5696 [==============================] - 50s 9ms/step - loss: 0.0094 - mean_absolute_error: 0.0722 - val_loss: 0.0024 - val_mean_absolute_error: 0.0350
# Epoch 28/30
# 5696/5696 [==============================] - 50s 9ms/step - loss: 0.0090 - mean_absolute_error: 0.0702 - val_loss: 0.0060 - val_mean_absolute_error: 0.0655
# Epoch 29/30
# 5696/5696 [==============================] - 50s 9ms/step - loss: 0.0090 - mean_absolute_error: 0.0700 - val_loss: 0.0048 - val_mean_absolute_error: 0.0603
# Epoch 30/30
# 5696/5696 [==============================] - 50s 9ms/step - loss: 0.0086 - mean_absolute_error: 0.0686 - val_loss: 0.0078 - val_mean_absolute_error: 0.0797

# %%
test_predicted = model.predict(test_data)
# Out:
# 1424/1424 [==============================] - 6s 2ms/step

# %%
predicted=pd.DataFrame(test_predicted)
predicted=predicted[[0]]
index=target_test.index.copy()
a=pd.DataFrame(index)
predicted=pd.concat([a, predicted], axis=1, ignore_index=True)
predicted.rename(columns = {0:'Date Time', 1:'T (degC)' }, inplace = True)
predicted .set_index('Date Time',drop=True,inplace=True)

# %%
predicted
# Out:
#                       T (degC)
# Date Time
# 2019-09-18 18:20:00  12.689032
# 2019-09-18 18:30:00  12.674259
# 2019-09-18 18:40:00  12.607139
# 2019-09-18 18:50:00  12.508421
# 2019-09-18 19:00:00  12.280206
# ...                        ...
# 2022-12-06 23:10:00  18.513590
# 2022-12-06 23:20:00  18.555824
# 2022-12-06 23:30:00  18.692379
# 2022-12-06 23:40:00  18.639799
# 2022-12-06 23:50:00  18.255936
#
# [45562 rows x 1 columns]

# %%
predictions=pd.concat([target_test,predicted], axis=1, ignore_index=True)
predictions.rename(columns = {0:'Actual Temperature (degC)', 1:'Predicted Temperature (degC)' }, inplace = True)

# %% [markdown]
# Actual vs Predictions

# %%
predictions
# Out:
#                      Actual Temperature (degC)  Predicted Temperature (degC)
# Date Time
# 2019-09-18 18:20:00                      12.62                     12.689032
# 2019-09-18 18:30:00                      12.60                     12.674259
# 2019-09-18 18:40:00                      12.53                     12.607139
# 2019-09-18 18:50:00                      12.44                     12.508421
# 2019-09-18 19:00:00                      12.21                     12.280206
# ...                                        ...                           ...
# 2022-12-06 23:10:00                      18.46                     18.513590
# 2022-12-06 23:20:00                      18.50                     18.555824
# 2022-12-06 23:30:00                      18.63                     18.692379
# 2022-12-06 23:40:00                      18.58                     18.639799
# 2022-12-06 23:50:00                      18.21                     18.255936
#
# [45562 rows x 2 columns]

# %%
before=target_train
actual=before.append(target_test)
after=target_train
pred=after.append(predicted)
# Out:
# C:\Users\pooji\AppData\Local\Temp\ipykernel_11752\3777245379.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   actual=before.append(target_test)
# C:\Users\pooji\AppData\Local\Temp\ipykernel_11752\3777245379.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pred=after.append(predicted)

# %% [markdown]
# ##### Performance Evaluation

# %%
mean_squared_error(y_true=target_test,
                   y_pred=predicted)
# Out:
# 0.007764871713314072

# %%
mean_absolute_error(y_true=target_test,
                   y_pred=predicted)
# Out:
# 0.07953900723256187

# %% [markdown]
# LSTM model has least error as compared to RandomForest and XGBoost for Weather Forecasting and hence LSTM model is the better option amongst RandomForest and XGBoost

# %% [markdown]
# Weather Forecast vs Actual

# %%
plt.figure(figsize=(30, 10))
plt.plot(actual, label='actual')
plt.plot(predicted, label='forecast')
plt.title('Temperature forecasts — absolute data')
plt.legend()
plt.show()

# %% [markdown]
# Inspecting the Predicted Range

# %%
plt.figure(figsize=(30, 10))
plt.plot(target_test, label='actual')
plt.plot(predicted, linestyle='dashed', label='forecast')
plt.title('Predicted Range')
plt.legend()
plt.show()

# %% [markdown]
# Inspecting some random small chunks

# %%
plt.figure(figsize=(30, 10))
plt.plot(target_test[150:200], label='actual')
plt.plot(predicted[150:200], linestyle='dashed', label='forecast')
plt.title('Close Range')
plt.legend()
plt.show()

# %% [markdown]
# The two lines are very close to each other, they basically overlap.
